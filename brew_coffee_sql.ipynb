# %% [markdown]
# ## Run KNN on dataset using sql

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ### Quality Measures
# Aroma, Flavor, Aftertaste, Acidity, Body, Balance, Uniformity, Cup Cleanliness, Sweetness, Moisture, Defects
#
# ### Bean Metadata
# Processing Method, Color, Species (arabica / robusta)
#
# ### Farm Metadata
# Owner, Country of Origin, Farm Name, Lot Number, Mill, Company, Altitude, Region

# %%
import numpy as np
import pandas as pd
import psycopg2
from psycopg2 import connect
import json 
from sqlalchemy import create_engine
# Out:
# /usr/local/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
# load json file in dir for db details

with open('config.json') as f:
    conf = json.load(f)

# %%
# use fstring to fill in items from the json document
login = f"postgresql://{conf['user']}:{conf['passw']}@{conf['host']}/coffee"

# %%
conn = create_engine(login).connect() # connect and fill db from csv file
df = pd.read_csv('/Users/sumac/projects/metis/project3/arabica_data_cleaned.csv') 
df.to_sql('arabica2', conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2227         try:
# -> 2228             return fn()
#    2229         except dialect.dbapi.Error as e:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     364         """
# --> 365         return _ConnectionFairy._checkout(self)
#     366
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     821         if not fairy:
# --> 822             fairy = _ConnectionRecord.checkout(pool)
#     823
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     553     def checkout(cls, pool):
# --> 554         rec = pool._do_get()
#     555         try:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1249                 with util.safe_reraise():
# -> 1250                     self._dec_overflow()
#    1251         else:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             if not self.warn_only:
# ---> 67                 compat.reraise(exc_type, exc_value, exc_tb)
#      68         else:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     276             raise value.with_traceback(tb)
# --> 277         raise value
#     278
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1246             try:
# -> 1247                 return self._create_connection()
#    1248             except:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     369
# --> 370         return _ConnectionRecord(self)
#     371
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     498         if connect:
# --> 499             self.__connect(first_connect_check=True)
#     500         self.finalize_callback = deque()
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     700             self.starttime = time.time()
# --> 701             connection = pool._invoke_creator(self)
#     702             pool.logger.debug("Created new connection %r", connection)
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     436     def connect(self, *cargs, **cparams):
# --> 437         return self.dbapi.connect(*cargs, **cparams)
#     438
#
# /usr/local/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#
# OperationalError: could not translate host name "covfefe-metis.c4dhyd2spzjx.us-west-1.rds.amazonaws.com" to address: nodename nor servname provided, or not known
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-b6fac4e41f72> in <module>()
# ----> 1 conn = create_engine(login).connect() # connect and fill db from csv file
#       2 df = pd.read_csv('/Users/sumac/projects/metis/project3/arabica_data_cleaned.csv')
#       3 df.to_sql('arabica2', conn)
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2169         """
#    2170
# -> 2171         return self._connection_cls(self, **kwargs)
#    2172
#    2173     def contextual_connect(self, close_with_result=False, **kwargs):
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2257         """
#    2258         return self._wrap_pool_connect(
# -> 2259             self.pool.unique_connection, _connection
#    2260         )
#    2261
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2230             if connection is None:
#    2231                 Connection._handle_dbapi_exception_noconnection(
# -> 2232                     e, dialect, self
#    2233                 )
#    2234             else:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1526             util.raise_from_cause(newraise, exc_info)
#    1527         elif should_wrap:
# -> 1528             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1529         else:
#    1530             util.reraise(*exc_info)
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2226         dialect = self.dialect
#    2227         try:
# -> 2228             return fn()
#    2229         except dialect.dbapi.Error as e:
#    2230             if connection is None:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     363
#     364         """
# --> 365         return _ConnectionFairy._checkout(self)
#     366
#     367     def _create_connection(self):
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     820     def _checkout(cls, pool, threadconns=None, fairy=None):
#     821         if not fairy:
# --> 822             fairy = _ConnectionRecord.checkout(pool)
#     823
#     824             fairy._pool = pool
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     552     @classmethod
#     553     def checkout(cls, pool):
# --> 554         rec = pool._do_get()
#     555         try:
#     556             dbapi_connection = rec.get_connection()
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1248             except:
#    1249                 with util.safe_reraise():
# -> 1250                     self._dec_overflow()
#    1251         else:
#    1252             return self._do_get()
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             self._exc_info = None  # remove potential circular references
#      66             if not self.warn_only:
# ---> 67                 compat.reraise(exc_type, exc_value, exc_tb)
#      68         else:
#      69             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     275         if value.__traceback__ is not tb:
#     276             raise value.with_traceback(tb)
# --> 277         raise value
#     278
#     279
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1245         if self._inc_overflow():
#    1246             try:
# -> 1247                 return self._create_connection()
#    1248             except:
#    1249                 with util.safe_reraise():
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     368         """Called by subclasses to create a new ConnectionRecord."""
#     369
# --> 370         return _ConnectionRecord(self)
#     371
#     372     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     497         self.__pool = pool
#     498         if connect:
# --> 499             self.__connect(first_connect_check=True)
#     500         self.finalize_callback = deque()
#     501
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     699         try:
#     700             self.starttime = time.time()
# --> 701             connection = pool._invoke_creator(self)
#     702             pool.logger.debug("Created new connection %r", connection)
#     703             self.connection = connection
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     435
#     436     def connect(self, *cargs, **cparams):
# --> 437         return self.dbapi.connect(*cargs, **cparams)
#     438
#     439     def create_connect_args(self, url):
#
# /usr/local/lib/python3.6/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     128
#     129     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 130     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     131     if cursor_factory is not None:
#     132         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not translate host name "covfefe-metis.c4dhyd2spzjx.us-west-1.rds.amazonaws.com" to address: nodename nor servname provided, or not known
#  (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
drop_columns = ['index','Species','Unnamed: 0', 'Owner','Farm.Name','Lot.Number', 'Mill', 'ICO.Number', 'Company', \
                         'Altitude', 'Region', 'Producer','Bag.Weight', 'In.Country.Partner','Harvest.Year', 'Grading.Date', \
                         'Owner.1','Variety','Color','Quakers','Expiration','Number.of.Bags', 'Certification.Body','Certification.Address', \
                         'Certification.Contact', 'unit_of_measurement']

column_names = ['Country.of.Origin', 'Processing.Method', 'Aroma', 'Flavor', 'Aftertaste', 'Acidity', \
                         'Body', 'Balance', 'Uniformity', 'Clean.Cup', 'Sweetness', 'Cupper.Points', \
                         'Total.Cup.Points', 'Moisture', 'Category.One.Defects', 'Category.Two.Defects', \
                         'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters']

# %%
drop_template = """ALTER TABLE arabica2
                    DROP COLUMN "{column_name}";"""

# %%
for drop_col in drop_columns: # loop to drop unneeded cols
    drop_statement = drop_template.format(column_name=drop_col) 
    conn.execute(drop_statement)

# %%
df = pd.read_sql("SELECT * FROM arabica2", con = conn)
df.head()

# %%
rename_col_template = """ALTER TABLE arabica2 RENAME COLUMN 
                        "{column_name}" TO "{new_column_name}";"""

# %%
for col in column_names: # loop to rename cols
    name_statement = rename_col_template.format(column_name=col, new_column_name=col.lower().replace('.','_'))
    conn.execute(name_statement)

# %%
df = pd.read_sql("SELECT * FROM arabica2", con = conn) # check to make sure things worked
df.head()
# Out:
#   country_of_origin processing_method  aroma  flavor  aftertaste  acidity  \
# 0          Ethiopia      Washed / Wet   8.67    8.83        8.67     8.75
# 1          Ethiopia      Washed / Wet   8.75    8.67        8.50     8.58
# 2         Guatemala              None   8.42    8.50        8.42     8.42
# 3          Ethiopia     Natural / Dry   8.17    8.58        8.42     8.42
# 4          Ethiopia      Washed / Wet   8.25    8.50        8.25     8.50
#
#    body  balance  uniformity  clean_cup  sweetness  cupper_points  \
# 0  8.50     8.42        10.0       10.0       10.0           8.75
# 1  8.42     8.42        10.0       10.0       10.0           8.58
# 2  8.33     8.42        10.0       10.0       10.0           9.25
# 3  8.50     8.25        10.0       10.0       10.0           8.67
# 4  8.42     8.33        10.0       10.0       10.0           8.58
#
#    total_cup_points  moisture  category_one_defects  category_two_defects  \
# 0             90.58      0.12                     0                     0
# 1             89.92      0.12                     0                     1
# 2             89.75      0.00                     0                     0
# 3             89.00      0.11                     0                     2
# 4             88.83      0.12                     0                     2
#
#    altitude_low_meters  altitude_high_meters  altitude_mean_meters
# 0               1950.0                2200.0                2075.0
# 1               1950.0                2200.0                2075.0
# 2               1600.0                1800.0                1700.0
# 3               1800.0                2200.0                2000.0
# 4               1950.0                2200.0                2075.0

# %%
df['processing_method'].isna().sum()
# Out:
# 152

# %%
data = df.dropna() # can figure out how to do this drop in sql later

# %%
data.dtypes
# Out:
# country_of_origin        object
# processing_method        object
# aroma                   float64
# flavor                  float64
# aftertaste              float64
# acidity                 float64
# body                    float64
# balance                 float64
# uniformity              float64
# clean_cup               float64
# sweetness               float64
# cupper_points           float64
# total_cup_points        float64
# moisture                float64
# category_one_defects      int64
# category_two_defects      int64
# altitude_low_meters     float64
# altitude_high_meters    float64
# altitude_mean_meters    float64
# dtype: object

# %%
dummy = pd.get_dummies(data, columns=['processing_method'], drop_first=True) # creating dummies in sql - possible?
dummy.head()
# Out:
#   country_of_origin  aroma  flavor  aftertaste  acidity  body  balance  \
# 0          Ethiopia   8.67    8.83        8.67     8.75  8.50     8.42
# 1          Ethiopia   8.75    8.67        8.50     8.58  8.42     8.42
# 3          Ethiopia   8.17    8.58        8.42     8.42  8.50     8.25
# 4          Ethiopia   8.25    8.50        8.25     8.50  8.42     8.33
# 9          Ethiopia   8.08    8.58        8.50     8.50  7.67     8.42
#
#    uniformity  clean_cup  sweetness               ...                moisture  \
# 0        10.0       10.0       10.0               ...                    0.12
# 1        10.0       10.0       10.0               ...                    0.12
# 3        10.0       10.0       10.0               ...                    0.11
# 4        10.0       10.0       10.0               ...                    0.12
# 9        10.0       10.0       10.0               ...                    0.10
#
#    category_one_defects  category_two_defects  altitude_low_meters  \
# 0                     0                     0               1950.0
# 1                     0                     1               1950.0
# 3                     0                     2               1800.0
# 4                     0                     2               1950.0
# 9                     0                     4               1795.0
#
#    altitude_high_meters  altitude_mean_meters  processing_method_Other  \
# 0                2200.0                2075.0                        0
# 1                2200.0                2075.0                        0
# 3                2200.0                2000.0                        0
# 4                2200.0                2075.0                        0
# 9                1850.0                1822.5                        0
#
#    processing_method_Pulped natural / honey  \
# 0                                         0
# 1                                         0
# 3                                         0
# 4                                         0
# 9                                         0
#
#    processing_method_Semi-washed / Semi-pulped  processing_method_Washed / Wet
# 0                                            0                               1
# 1                                            0                               1
# 3                                            0                               0
# 4                                            0                               1
# 9                                            0                               0
#
# [5 rows x 22 columns]

# %%
#add region column
regions = { 'United States': 'north_america',
           'Mexico': 'north_america',
           'China' : 'asia',
           'Taiwan': 'asia',
           'Japan':'asia',
           'El Salvador': 'central_america_carib',
           'Nicaragua': 'central_america_carib',
           'Costa Rica': 'central_america_carib',
           'Guatemala':'central_america_carib',
           'Honduras':'central_america_carib',
           'Haiti':'central_america_carib',
           'United States (Puerto Rico)':'central_america_carib',
           'Brazil' : 'south_america',
           'Peru': 'south_america',
           'Colombia':  'south_america',
           'Panama': 'south_america',
           'Ecuador': 'south_america',
           'Ethiopia':'africa',
           'Kenya': 'africa',
           'Burundi':'africa',
           'Cote d?Ivoire':'africa',
           'Rwanda':'africa',
           'Malawi':'africa',
           'Uganda':'africa',
           'Tanzania, United Republic Of': 'africa',
           'Zambia': 'africa',
           'Thailand':'southeast_asia',
           'Myanmar':'southeast_asia',
           'Indonesia':'southeast_asia',
           'Papua New Guinea':'southeast_asia',
           'Vietnam':'southeast_asia',
           'Philippines':'southeast_asia',
           'Laos':'southeast_asia'
          }

def get_region(search_country): 
    for (country, region) in regions.items():
            if country == search_country:
                return region

# %%
region_list=[]

for row in dummy['country_of_origin']:
    print(get_region(row))
    region_list.append(get_region(row))
    
dummy['region'] = region_list
# Out:
# africa
# africa
# africa
# africa
# africa
# africa
# north_america
# north_america
# north_america
# asia
# africa
# north_america
# central_america_carib
# north_america
# north_america
# south_america
# africa
# asia
# south_america
# central_america_carib
# africa
# africa
# north_america
# southeast_asia
# asia
# africa
# south_america
# south_america
# africa
# africa
# africa
# south_america
# south_america
# africa
# central_america_carib
# central_america_carib
# southeast_asia
# central_america_carib
# central_america_carib
# south_america
# africa
# africa
# africa
# central_america_carib
# africa
# africa
# south_america
# asia
# central_america_carib
# central_america_carib
# central_america_carib
# africa
# africa
# south_america
# south_america
# southeast_asia
# central_america_carib
# south_america
# africa
# south_america
# africa
# central_america_carib
# north_america
# africa
# africa
# south_america
# south_america
# asia
# africa
# south_america
# north_america
# south_america
# south_america
# asia
# africa
# africa
# central_america_carib
# central_america_carib
# southeast_asia
# asia
# central_america_carib
# central_america_carib
# central_america_carib
# africa
# central_america_carib
# central_america_carib
# asia
# south_america
# africa
# central_america_carib
# central_america_carib
# north_america
# africa
# africa
# south_america
# africa
# central_america_carib
# central_america_carib
# south_america
# south_america
# south_america
# central_america_carib
# south_america
# south_america
# south_america
# central_america_carib
# africa
# asia
# central_america_carib
# south_america
# asia
# central_america_carib
# africa
# north_america
# north_america
# north_america
# asia
# north_america
# central_america_carib
# central_america_carib
# central_america_carib
# central_america_carib
# north_america
# north_america
# central_america_carib
# central_america_carib
# north_america
# north_america
# north_america
# central_america_carib
# central_america_carib
# south_america
# north_america
# north_america
# north_america
# north_america
# north_america
# central_america_carib
# central_america_carib
# north_america
# north_america
# north_america
# asia
# north_america
# central_america_carib
# asia
# north_america
# north_america
# north_america
# north_america
# north_america
# north_america
# central_america_carib
# central_america_carib
# north_america
# southeast_asia
# north_america
# asia
# central_america_carib
# central_america_carib
# asia
# central_america_carib
# north_america
# central_america_carib
# north_america
# central_america_carib
# asia
# north_america
# central_america_carib
# south_america
# central_america_carib
# north_america
# central_america_carib
# north_america
# south_america
# north_america
# central_america_carib
# north_america
# southeast_asia
# north_america
# central_america_carib
# southeast_asia
# central_america_carib
# north_america
# north_america
# north_america
# north_america
# north_america
# north_america
# north_america
# north_america
# central_america_carib
# north_america
# north_america
# north_america
# central_america_carib
# north_america
# central_america_carib
# north_america
# north_america
# north_america
# central_america_carib
# central_america_carib
# central_america_carib
# north_america
# central_america_carib
# central_america_carib
# central_america_carib

# %%
dummy.shape
# Out:
# (1005, 23)

# %%
dummy.to_csv('arabica_to_classify.csv') # export and check the csv
csv_check = pd.DataFrame.from_csv('arabica_to_classify.csv')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
csv_check = pd.DataFrame.from_csv('arabica_to_classify.csv')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
csv_check.head()
# Out:
#   country_of_origin  aroma  flavor  aftertaste  acidity  body  balance  \
# 0          Ethiopia   8.67    8.83        8.67     8.75  8.50     8.42
# 1          Ethiopia   8.75    8.67        8.50     8.58  8.42     8.42
# 3          Ethiopia   8.17    8.58        8.42     8.42  8.50     8.25
# 4          Ethiopia   8.25    8.50        8.25     8.50  8.42     8.33
# 9          Ethiopia   8.08    8.58        8.50     8.50  7.67     8.42
#
#    uniformity  clean_cup  sweetness   ...    category_one_defects  \
# 0        10.0       10.0       10.0   ...                       0
# 1        10.0       10.0       10.0   ...                       0
# 3        10.0       10.0       10.0   ...                       0
# 4        10.0       10.0       10.0   ...                       0
# 9        10.0       10.0       10.0   ...                       0
#
#    category_two_defects  altitude_low_meters  altitude_high_meters  \
# 0                     0               1950.0                2200.0
# 1                     1               1950.0                2200.0
# 3                     2               1800.0                2200.0
# 4                     2               1950.0                2200.0
# 9                     4               1795.0                1850.0
#
#    altitude_mean_meters  processing_method_Other  \
# 0                2075.0                        0
# 1                2075.0                        0
# 3                2000.0                        0
# 4                2075.0                        0
# 9                1822.5                        0
#
#    processing_method_Pulped natural / honey  \
# 0                                         0
# 1                                         0
# 3                                         0
# 4                                         0
# 9                                         0
#
#    processing_method_Semi-washed / Semi-pulped  \
# 0                                            0
# 1                                            0
# 3                                            0
# 4                                            0
# 9                                            0
#
#    processing_method_Washed / Wet  region
# 0                               1  africa
# 1                               1  africa
# 3                               0  africa
# 4                               1  africa
# 9                               0  africa
#
# [5 rows x 23 columns]

# %%
csv_check.shape
# Out:
# (1005, 23)

# %%
#where did the unnamed col come from??? using read_csv breaks the csv
